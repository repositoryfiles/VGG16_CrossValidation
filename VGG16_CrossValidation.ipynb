# %%
# googledrive の使用
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import glob
import os

import numpy as np
from keras.applications.vgg16 import VGG16
from keras.callbacks import (CSVLogger, EarlyStopping, ModelCheckpoint, ReduceLROnPlateau)
from keras.layers import Dense, Dropout, GlobalAveragePooling2D, Input
from keras.models import Model
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
from PIL import Image, ImageOps
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt

# 画像データ（種類ごとにフォルダに格納）と出力ファイル（.h5など）のフォルダ指定
# GoogleColaboratoryで動かす場合の設定例
# 画像ファイルは、fractureの下にDimple、Rock、Striationなどのカテゴリ名を付けたフォルダに格納
data_path = '/content/gdrive/My Drive/data/fracture'
output_path = '/content/gdrive/My Drive/data'

# ローカルパソコンで動かす場合の設定例
# 画像ファイルは、fractureの下にDimple、Rock、Striationなどのカテゴリ名を付けたフォルダに格納
# data_path = "c:/data/fracture"
# output_path = "c:/data"

IMAGE_SIZE = 224 # 画像サイズ（ここでは使用するモデルの最大サイズを指定）
BATCH_SIZE = 16 # バッチサイズ
NB_EPOCH = 50 # 学習の最大回数
FOLD = 5 # 交差検証の回数

# ラベル名
# fractureの下のフォルダ名をラベル名とする（フォルダ名は全角文字不可）
labels = os.listdir(data_path)
print(labels)

# ラベル数
nb_classes = len(labels)
print(nb_classes)

# モデルの構築
def build_model():

    input_tensor = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
    base_model = VGG16(weights='imagenet', include_top=False, input_tensor=input_tensor)

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.20)(x) # 0.10の値は適宜変更
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.20)(x) # 0.10の値は適宜変更
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.20)(x) # 0.10の値は適宜変更
    predictions = Dense(nb_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)


#model.add(Conv2D(64, kernel_size=3, padding="same", activation="relu"))
#model.add(MaxPooling2D())
#model.add(Dropout(0.25))

#model.add(Flatten())
#model.add(Dense(256, activation='relu'))
#model.add(Dropout(0.5))
#model.add(Dense(128, activation="relu"))
#model.add(Dense(64, activation="relu"))
#model.add(Dropout(0.5))
#model.add(Dense(10, activation='softmax'))
#model.summary()


    # ファインチューニング
    for layer in model.layers[:15]:
        layer.trainable = False
    for layer in model.layers[15:]:
        layer.trainable = True

    # ラベルデータの整数値を2値クラスの行列とするため、loss='categorical_crossentropy'を使う
    model.compile(optimizer=Adam(learning_rate=0.0002), loss='categorical_crossentropy', metrics=['accuracy']) # learning_rateは適宜調整

    return model

# データの初期化
X = []
y = []

# データの読み込み
for index, name in enumerate(labels):
    data_dir = data_path + '/' + name
    data_files = glob.glob(data_dir + "/*.*")
    for i, data_file in enumerate(data_files):

        image = Image.open(data_file)
        image = image.convert("RGB")

        im = ImageOps.fit(
            image, (IMAGE_SIZE, IMAGE_SIZE), Image.Resampling.LANCZOS
        )
        data = np.asarray(im)
        X.append(data)
        y.append(index)

X = np.array(X)
y = np.array(y)

data_num = len(X)
steps_per_epoch = data_num * (7 / 10) / BATCH_SIZE
print(steps_per_epoch)

valid_scores = []
models = []

# 交差検証
kf = KFold(n_splits=FOLD, shuffle=True, random_state=42)
for fold, (train_indices, valid_indices) in enumerate(kf.split(X)):

    # 学習データと検証データに分ける
    X_train, X_valid = X[train_indices], X[valid_indices]
    y_train, y_valid = y[train_indices], y[valid_indices]

    # ラベルデータの整数値を2値クラスの行列に変換（例 2番目のラベルを「0,1,0,0,0」と表現）
    y_train = to_categorical(y_train, nb_classes)
    y_valid = to_categorical(y_valid, nb_classes)

    # モデルの呼び出し
    model = build_model()

    # 学習用画像のアレンジの仕方を定義
    train_datagen = ImageDataGenerator(
        rescale=1.0 / 255, # 画素値の正規化（0～255を0～1に）
        # 水増しの条件は適宜変更
        width_shift_range=0.1,
        height_shift_range=0.1,
        rotation_range=30,
        channel_shift_range=50,
        brightness_range=[0.3, 1.0],
        horizontal_flip=True,
        vertical_flip=True,
    )

    # アレンジした学習用画像生成
    train_datagen.fit(X_train)

    # 検証用画像の生成（正規化のみ実行）
    valid_datagen = ImageDataGenerator(rescale=1.0 / 255) # 画素値の正規化（0～255を0～1に）
    valid_datagen.fit(X_valid)

    # 学習結果のファイル名定義
    ResultFileName = output_path + '/' + 'VGG16model' + str(fold+1)

    # 学習経過のファイル名定義
    csv_log = CSVLogger(
        ResultFileName + '.csv'
    )

    # 学習終了の条件定義
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=5,
        verbose=1
    )

    # 学習率の更新条件定義
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=2,
        verbose=1
    )

    # モデルの重みを一定頻度で保存
    modelCheckpoint = ModelCheckpoint(
        filepath = ResultFileName + '.h5',
        monitor='val_loss',
        verbose=1,
        save_best_only=True,
        save_weights_only=False,
        mode='min',
        save_freq='epoch'
    )

    # 学習
    history = model.fit(
        train_datagen.flow(X_train, y_train, batch_size = BATCH_SIZE),
        epochs = NB_EPOCH,
        steps_per_epoch = steps_per_epoch,
        validation_steps = 1,
        verbose=1,
        validation_data = valid_datagen.flow(X_valid, y_valid),
        callbacks = [csv_log, early_stopping, reduce_lr, modelCheckpoint]
    )

    # 検証
    y_valid_pred = model.predict(X_valid)

    # MAEの計算
    score = mean_absolute_error(y_valid, y_valid_pred)
    print(f'fold {fold} MAE: {score}')
    valid_scores.append(score)
    models.append(model)

    # 学習結果のグラフ表示
    acc = history.history["accuracy"]
    val_acc = history.history["val_accuracy"]
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(len(acc))
    plt.plot(epochs, acc, "bo", label="Training")
    plt.plot(epochs, val_acc, "b", label="Validation")
    plt.title("Training and validation accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.figure()
    plt.plot(epochs, loss, "bo", label="Training")
    plt.plot(epochs, val_loss, "b", label="Validation")
    plt.title("Training and validation loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()


# MEAの平均値
cv_score = np.mean(valid_scores)
print(f'CV score: {cv_score}')
# Out:
# ['Rock', 'Fan-shaped', 'River', 'Dimple', 'Striation']
# 5
# 7.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step
# Epoch 1/50
# 7/7 [==============================] - ETA: 0s - loss: 1.6233 - accuracy: 0.2143
# Epoch 1: val_loss improved from inf to 1.48124, saving model to /content/gdrive/My Drive/data/VGG16model1.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7/7 [==============================] - 37s 4s/step - loss: 1.6233 - accuracy: 0.2143 - val_loss: 1.4812 - val_accuracy: 0.3750 - lr: 2.0000e-04
# Epoch 2/50
# 7/7 [==============================] - ETA: 0s - loss: 1.5604 - accuracy: 0.2768
# Epoch 2: val_loss improved from 1.48124 to 1.15597, saving model to /content/gdrive/My Drive/data/VGG16model1.h5
# 7/7 [==============================] - 2s 340ms/step - loss: 1.5604 - accuracy: 0.2768 - val_loss: 1.1560 - val_accuracy: 0.5312 - lr: 2.0000e-04
# Epoch 3/50
# 7/7 [==============================] - ETA: 0s - loss: 1.3919 - accuracy: 0.4018
# Epoch 3: val_loss improved from 1.15597 to 0.86812, saving model to /content/gdrive/My Drive/data/VGG16model1.h5
# 7/7 [==============================] - 2s 341ms/step - loss: 1.3919 - accuracy: 0.4018 - val_loss: 0.8681 - val_accuracy: 0.5938 - lr: 2.0000e-04
# Epoch 4/50
# 7/7 [==============================] - ETA: 0s - loss: 1.1629 - accuracy: 0.5268
# Epoch 4: val_loss improved from 0.86812 to 0.86022, saving model to /content/gdrive/My Drive/data/VGG16model1.h5
# 7/7 [==============================] - 4s 518ms/step - loss: 1.1629 - accuracy: 0.5268 - val_loss: 0.8602 - val_accuracy: 0.6562 - lr: 2.0000e-04
# Epoch 5/50
# 7/7 [==============================] - ETA: 0s - loss: 1.2179 - accuracy: 0.4911
# Epoch 5: val_loss did not improve from 0.86022
# 7/7 [==============================] - 2s 283ms/step - loss: 1.2179 - accuracy: 0.4911 - val_loss: 1.0515 - val_accuracy: 0.5938 - lr: 2.0000e-04
# Epoch 6/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9185 - accuracy: 0.6250
# Epoch 6: val_loss improved from 0.86022 to 0.62420, saving model to /content/gdrive/My Drive/data/VGG16model1.h5
# 7/7 [==============================] - 2s 344ms/step - loss: 0.9185 - accuracy: 0.6250 - val_loss: 0.6242 - val_accuracy: 0.7188 - lr: 2.0000e-04
# Epoch 7/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9377 - accuracy: 0.5893
# Epoch 7: val_loss did not improve from 0.62420
# 7/7 [==============================] - 2s 264ms/step - loss: 0.9377 - accuracy: 0.5893 - val_loss: 0.7615 - val_accuracy: 0.7500 - lr: 2.0000e-04
# Epoch 8/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9188 - accuracy: 0.5893
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
#
# Epoch 8: val_loss did not improve from 0.62420
# 7/7 [==============================] - 2s 265ms/step - loss: 0.9188 - accuracy: 0.5893 - val_loss: 0.6595 - val_accuracy: 0.7500 - lr: 2.0000e-04
# Epoch 9/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7498 - accuracy: 0.6786
# Epoch 9: val_loss improved from 0.62420 to 0.33301, saving model to /content/gdrive/My Drive/data/VGG16model1.h5
# 7/7 [==============================] - 4s 580ms/step - loss: 0.7498 - accuracy: 0.6786 - val_loss: 0.3330 - val_accuracy: 0.8750 - lr: 1.0000e-04
# Epoch 10/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5467 - accuracy: 0.7679
# Epoch 10: val_loss improved from 0.33301 to 0.30739, saving model to /content/gdrive/My Drive/data/VGG16model1.h5
# 7/7 [==============================] - 2s 352ms/step - loss: 0.5467 - accuracy: 0.7679 - val_loss: 0.3074 - val_accuracy: 0.8750 - lr: 1.0000e-04
# Epoch 11/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6555 - accuracy: 0.7143
# Epoch 11: val_loss improved from 0.30739 to 0.28970, saving model to /content/gdrive/My Drive/data/VGG16model1.h5
# 7/7 [==============================] - 2s 349ms/step - loss: 0.6555 - accuracy: 0.7143 - val_loss: 0.2897 - val_accuracy: 0.8750 - lr: 1.0000e-04
# Epoch 12/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5310 - accuracy: 0.7679
# Epoch 12: val_loss improved from 0.28970 to 0.28389, saving model to /content/gdrive/My Drive/data/VGG16model1.h5
# 7/7 [==============================] - 2s 344ms/step - loss: 0.5310 - accuracy: 0.7679 - val_loss: 0.2839 - val_accuracy: 0.8750 - lr: 1.0000e-04
# Epoch 13/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6285 - accuracy: 0.7500
# Epoch 13: val_loss improved from 0.28389 to 0.23102, saving model to /content/gdrive/My Drive/data/VGG16model1.h5
# 7/7 [==============================] - 2s 366ms/step - loss: 0.6285 - accuracy: 0.7500 - val_loss: 0.2310 - val_accuracy: 0.9062 - lr: 1.0000e-04
# Epoch 14/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5357 - accuracy: 0.7768
# Epoch 14: val_loss did not improve from 0.23102
# 7/7 [==============================] - 3s 441ms/step - loss: 0.5357 - accuracy: 0.7768 - val_loss: 0.2879 - val_accuracy: 0.8750 - lr: 1.0000e-04
# Epoch 15/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4231 - accuracy: 0.8750
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 15: val_loss did not improve from 0.23102
# 7/7 [==============================] - 2s 260ms/step - loss: 0.4231 - accuracy: 0.8750 - val_loss: 0.4265 - val_accuracy: 0.8438 - lr: 1.0000e-04
# Epoch 16/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3913 - accuracy: 0.8661
# Epoch 16: val_loss did not improve from 0.23102
# 7/7 [==============================] - 2s 285ms/step - loss: 0.3913 - accuracy: 0.8661 - val_loss: 0.2577 - val_accuracy: 0.8438 - lr: 5.0000e-05
# Epoch 17/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4489 - accuracy: 0.8214
# Epoch 17: val_loss improved from 0.23102 to 0.18179, saving model to /content/gdrive/My Drive/data/VGG16model1.h5
# 7/7 [==============================] - 3s 417ms/step - loss: 0.4489 - accuracy: 0.8214 - val_loss: 0.1818 - val_accuracy: 0.9062 - lr: 5.0000e-05
# Epoch 18/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4099 - accuracy: 0.8125
# Epoch 18: val_loss did not improve from 0.18179
# 7/7 [==============================] - 2s 263ms/step - loss: 0.4099 - accuracy: 0.8125 - val_loss: 0.3228 - val_accuracy: 0.8750 - lr: 5.0000e-05
# Epoch 19/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4073 - accuracy: 0.8304
# Epoch 19: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 19: val_loss did not improve from 0.18179
# 7/7 [==============================] - 3s 388ms/step - loss: 0.4073 - accuracy: 0.8304 - val_loss: 0.2647 - val_accuracy: 0.8750 - lr: 5.0000e-05
# Epoch 20/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3594 - accuracy: 0.8571
# Epoch 20: val_loss did not improve from 0.18179
# 7/7 [==============================] - 2s 335ms/step - loss: 0.3594 - accuracy: 0.8571 - val_loss: 0.2728 - val_accuracy: 0.8750 - lr: 2.5000e-05
# Epoch 21/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4372 - accuracy: 0.8571
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 21: val_loss did not improve from 0.18179
# 7/7 [==============================] - 2s 261ms/step - loss: 0.4372 - accuracy: 0.8571 - val_loss: 0.2541 - val_accuracy: 0.9062 - lr: 2.5000e-05
# Epoch 22/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3823 - accuracy: 0.8661
# Epoch 22: val_loss did not improve from 0.18179
# 7/7 [==============================] - 2s 285ms/step - loss: 0.3823 - accuracy: 0.8661 - val_loss: 0.2189 - val_accuracy: 0.9375 - lr: 1.2500e-05
# Epoch 22: early stopping
# 1/1 [==============================] - 0s 194ms/step
# fold 0 MAE: 0.26435208320617676
# Epoch 1/50
# 7/7 [==============================] - ETA: 0s - loss: 1.6069 - accuracy: 0.2679
# Epoch 1: val_loss improved from inf to 1.42589, saving model to /content/gdrive/My Drive/data/VGG16model2.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7/7 [==============================] - 19s 3s/step - loss: 1.6069 - accuracy: 0.2679 - val_loss: 1.4259 - val_accuracy: 0.4688 - lr: 2.0000e-04
# Epoch 2/50
# 7/7 [==============================] - ETA: 0s - loss: 1.3568 - accuracy: 0.4732
# Epoch 2: val_loss improved from 1.42589 to 1.19772, saving model to /content/gdrive/My Drive/data/VGG16model2.h5
# 7/7 [==============================] - 3s 370ms/step - loss: 1.3568 - accuracy: 0.4732 - val_loss: 1.1977 - val_accuracy: 0.4375 - lr: 2.0000e-04
# Epoch 3/50
# 7/7 [==============================] - ETA: 0s - loss: 1.2307 - accuracy: 0.4375
# Epoch 3: val_loss did not improve from 1.19772
# 7/7 [==============================] - 2s 272ms/step - loss: 1.2307 - accuracy: 0.4375 - val_loss: 1.2239 - val_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 4/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0356 - accuracy: 0.5625
# Epoch 4: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
#
# Epoch 4: val_loss did not improve from 1.19772
# 7/7 [==============================] - 2s 261ms/step - loss: 1.0356 - accuracy: 0.5625 - val_loss: 1.2027 - val_accuracy: 0.5312 - lr: 2.0000e-04
# Epoch 5/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0097 - accuracy: 0.6339
# Epoch 5: val_loss improved from 1.19772 to 1.15442, saving model to /content/gdrive/My Drive/data/VGG16model2.h5
# 7/7 [==============================] - 3s 439ms/step - loss: 1.0097 - accuracy: 0.6339 - val_loss: 1.1544 - val_accuracy: 0.6250 - lr: 1.0000e-04
# Epoch 6/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9645 - accuracy: 0.6071
# Epoch 6: val_loss improved from 1.15442 to 1.07811, saving model to /content/gdrive/My Drive/data/VGG16model2.h5
# 7/7 [==============================] - 3s 469ms/step - loss: 0.9645 - accuracy: 0.6071 - val_loss: 1.0781 - val_accuracy: 0.6250 - lr: 1.0000e-04
# Epoch 7/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7993 - accuracy: 0.6518
# Epoch 7: val_loss improved from 1.07811 to 0.95490, saving model to /content/gdrive/My Drive/data/VGG16model2.h5
# 7/7 [==============================] - 3s 389ms/step - loss: 0.7993 - accuracy: 0.6518 - val_loss: 0.9549 - val_accuracy: 0.7812 - lr: 1.0000e-04
# Epoch 8/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7135 - accuracy: 0.6964
# Epoch 8: val_loss did not improve from 0.95490
# 7/7 [==============================] - 2s 280ms/step - loss: 0.7135 - accuracy: 0.6964 - val_loss: 1.1979 - val_accuracy: 0.7188 - lr: 1.0000e-04
# Epoch 9/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7501 - accuracy: 0.6250
# Epoch 9: val_loss improved from 0.95490 to 0.78512, saving model to /content/gdrive/My Drive/data/VGG16model2.h5
# 7/7 [==============================] - 2s 340ms/step - loss: 0.7501 - accuracy: 0.6250 - val_loss: 0.7851 - val_accuracy: 0.7812 - lr: 1.0000e-04
# Epoch 10/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7848 - accuracy: 0.6786
# Epoch 10: val_loss did not improve from 0.78512
# 7/7 [==============================] - 2s 293ms/step - loss: 0.7848 - accuracy: 0.6786 - val_loss: 1.3409 - val_accuracy: 0.6875 - lr: 1.0000e-04
# Epoch 11/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7380 - accuracy: 0.6696
# Epoch 11: val_loss improved from 0.78512 to 0.71309, saving model to /content/gdrive/My Drive/data/VGG16model2.h5
# 7/7 [==============================] - 3s 435ms/step - loss: 0.7380 - accuracy: 0.6696 - val_loss: 0.7131 - val_accuracy: 0.7188 - lr: 1.0000e-04
# Epoch 12/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5147 - accuracy: 0.7768
# Epoch 12: val_loss did not improve from 0.71309
# 7/7 [==============================] - 2s 264ms/step - loss: 0.5147 - accuracy: 0.7768 - val_loss: 0.8360 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 13/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5254 - accuracy: 0.7946
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 13: val_loss did not improve from 0.71309
# 7/7 [==============================] - 2s 282ms/step - loss: 0.5254 - accuracy: 0.7946 - val_loss: 0.8263 - val_accuracy: 0.8438 - lr: 1.0000e-04
# Epoch 14/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4363 - accuracy: 0.8214
# Epoch 14: val_loss did not improve from 0.71309
# 7/7 [==============================] - 2s 278ms/step - loss: 0.4363 - accuracy: 0.8214 - val_loss: 0.9209 - val_accuracy: 0.7500 - lr: 5.0000e-05
# Epoch 15/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4970 - accuracy: 0.8036
# Epoch 15: val_loss improved from 0.71309 to 0.65658, saving model to /content/gdrive/My Drive/data/VGG16model2.h5
# 7/7 [==============================] - 4s 695ms/step - loss: 0.4970 - accuracy: 0.8036 - val_loss: 0.6566 - val_accuracy: 0.8750 - lr: 5.0000e-05
# Epoch 16/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3846 - accuracy: 0.8661
# Epoch 16: val_loss did not improve from 0.65658
# 7/7 [==============================] - 2s 294ms/step - loss: 0.3846 - accuracy: 0.8661 - val_loss: 0.7478 - val_accuracy: 0.8750 - lr: 5.0000e-05
# Epoch 17/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3713 - accuracy: 0.8750
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 17: val_loss did not improve from 0.65658
# 7/7 [==============================] - 2s 285ms/step - loss: 0.3713 - accuracy: 0.8750 - val_loss: 0.7740 - val_accuracy: 0.8438 - lr: 5.0000e-05
# Epoch 18/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4538 - accuracy: 0.7946
# Epoch 18: val_loss improved from 0.65658 to 0.64321, saving model to /content/gdrive/My Drive/data/VGG16model2.h5
# 7/7 [==============================] - 2s 329ms/step - loss: 0.4538 - accuracy: 0.7946 - val_loss: 0.6432 - val_accuracy: 0.8438 - lr: 2.5000e-05
# Epoch 19/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3495 - accuracy: 0.8482
# Epoch 19: val_loss improved from 0.64321 to 0.62639, saving model to /content/gdrive/My Drive/data/VGG16model2.h5
# 7/7 [==============================] - 2s 361ms/step - loss: 0.3495 - accuracy: 0.8482 - val_loss: 0.6264 - val_accuracy: 0.8438 - lr: 2.5000e-05
# Epoch 20/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4104 - accuracy: 0.8661
# Epoch 20: val_loss improved from 0.62639 to 0.58614, saving model to /content/gdrive/My Drive/data/VGG16model2.h5
# 7/7 [==============================] - 3s 479ms/step - loss: 0.4104 - accuracy: 0.8661 - val_loss: 0.5861 - val_accuracy: 0.8750 - lr: 2.5000e-05
# Epoch 21/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3157 - accuracy: 0.8661
# Epoch 21: val_loss improved from 0.58614 to 0.53188, saving model to /content/gdrive/My Drive/data/VGG16model2.h5
# 7/7 [==============================] - 3s 365ms/step - loss: 0.3157 - accuracy: 0.8661 - val_loss: 0.5319 - val_accuracy: 0.8438 - lr: 2.5000e-05
# Epoch 22/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3126 - accuracy: 0.9018
# Epoch 22: val_loss did not improve from 0.53188
# 7/7 [==============================] - 3s 425ms/step - loss: 0.3126 - accuracy: 0.9018 - val_loss: 0.5904 - val_accuracy: 0.8750 - lr: 2.5000e-05
# Epoch 23/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3988 - accuracy: 0.8571
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 23: val_loss did not improve from 0.53188
# 7/7 [==============================] - 2s 291ms/step - loss: 0.3988 - accuracy: 0.8571 - val_loss: 0.6889 - val_accuracy: 0.8750 - lr: 2.5000e-05
# Epoch 24/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2749 - accuracy: 0.9196
# Epoch 24: val_loss did not improve from 0.53188
# 7/7 [==============================] - 3s 391ms/step - loss: 0.2749 - accuracy: 0.9196 - val_loss: 0.5859 - val_accuracy: 0.8750 - lr: 1.2500e-05
# Epoch 25/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3149 - accuracy: 0.8839
# Epoch 25: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 25: val_loss did not improve from 0.53188
# 7/7 [==============================] - 2s 293ms/step - loss: 0.3149 - accuracy: 0.8839 - val_loss: 0.5713 - val_accuracy: 0.8438 - lr: 1.2500e-05
# Epoch 26/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3178 - accuracy: 0.8750
# Epoch 26: val_loss did not improve from 0.53188
# 7/7 [==============================] - 2s 282ms/step - loss: 0.3178 - accuracy: 0.8750 - val_loss: 0.5681 - val_accuracy: 0.8438 - lr: 6.2500e-06
# Epoch 26: early stopping
# 1/1 [==============================] - 0s 157ms/step
# fold 1 MAE: 0.1868669092655182
# Epoch 1/50
# 7/7 [==============================] - ETA: 0s - loss: 1.6617 - accuracy: 0.2143
# Epoch 1: val_loss improved from inf to 1.44526, saving model to /content/gdrive/My Drive/data/VGG16model3.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7/7 [==============================] - 17s 2s/step - loss: 1.6617 - accuracy: 0.2143 - val_loss: 1.4453 - val_accuracy: 0.4375 - lr: 2.0000e-04
# Epoch 2/50
# 7/7 [==============================] - ETA: 0s - loss: 1.4695 - accuracy: 0.3661
# Epoch 2: val_loss improved from 1.44526 to 1.44271, saving model to /content/gdrive/My Drive/data/VGG16model3.h5
# 7/7 [==============================] - 2s 350ms/step - loss: 1.4695 - accuracy: 0.3661 - val_loss: 1.4427 - val_accuracy: 0.3125 - lr: 2.0000e-04
# Epoch 3/50
# 7/7 [==============================] - ETA: 0s - loss: 1.3639 - accuracy: 0.4107
# Epoch 3: val_loss improved from 1.44271 to 1.02982, saving model to /content/gdrive/My Drive/data/VGG16model3.h5
# 7/7 [==============================] - 2s 358ms/step - loss: 1.3639 - accuracy: 0.4107 - val_loss: 1.0298 - val_accuracy: 0.5938 - lr: 2.0000e-04
# Epoch 4/50
# 7/7 [==============================] - ETA: 0s - loss: 1.2198 - accuracy: 0.4375
# Epoch 4: val_loss improved from 1.02982 to 0.91986, saving model to /content/gdrive/My Drive/data/VGG16model3.h5
# 7/7 [==============================] - 3s 370ms/step - loss: 1.2198 - accuracy: 0.4375 - val_loss: 0.9199 - val_accuracy: 0.6250 - lr: 2.0000e-04
# Epoch 5/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0450 - accuracy: 0.5357
# Epoch 5: val_loss improved from 0.91986 to 0.75623, saving model to /content/gdrive/My Drive/data/VGG16model3.h5
# 7/7 [==============================] - 3s 390ms/step - loss: 1.0450 - accuracy: 0.5357 - val_loss: 0.7562 - val_accuracy: 0.7188 - lr: 2.0000e-04
# Epoch 6/50
# 7/7 [==============================] - ETA: 0s - loss: 1.1292 - accuracy: 0.5625
# Epoch 6: val_loss did not improve from 0.75623
# 7/7 [==============================] - 3s 408ms/step - loss: 1.1292 - accuracy: 0.5625 - val_loss: 1.0197 - val_accuracy: 0.5625 - lr: 2.0000e-04
# Epoch 7/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9406 - accuracy: 0.6607
# Epoch 7: val_loss improved from 0.75623 to 0.71640, saving model to /content/gdrive/My Drive/data/VGG16model3.h5
# 7/7 [==============================] - 2s 344ms/step - loss: 0.9406 - accuracy: 0.6607 - val_loss: 0.7164 - val_accuracy: 0.7500 - lr: 2.0000e-04
# Epoch 8/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7945 - accuracy: 0.6607
# Epoch 8: val_loss improved from 0.71640 to 0.65128, saving model to /content/gdrive/My Drive/data/VGG16model3.h5
# 7/7 [==============================] - 2s 351ms/step - loss: 0.7945 - accuracy: 0.6607 - val_loss: 0.6513 - val_accuracy: 0.8125 - lr: 2.0000e-04
# Epoch 9/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6048 - accuracy: 0.7946
# Epoch 9: val_loss improved from 0.65128 to 0.60656, saving model to /content/gdrive/My Drive/data/VGG16model3.h5
# 7/7 [==============================] - 2s 337ms/step - loss: 0.6048 - accuracy: 0.7946 - val_loss: 0.6066 - val_accuracy: 0.8750 - lr: 2.0000e-04
# Epoch 10/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6671 - accuracy: 0.7232
# Epoch 10: val_loss did not improve from 0.60656
# 7/7 [==============================] - 2s 281ms/step - loss: 0.6671 - accuracy: 0.7232 - val_loss: 0.6437 - val_accuracy: 0.8125 - lr: 2.0000e-04
# Epoch 11/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7266 - accuracy: 0.7411
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
#
# Epoch 11: val_loss did not improve from 0.60656
# 7/7 [==============================] - 3s 404ms/step - loss: 0.7266 - accuracy: 0.7411 - val_loss: 0.6302 - val_accuracy: 0.7188 - lr: 2.0000e-04
# Epoch 12/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5582 - accuracy: 0.7946
# Epoch 12: val_loss did not improve from 0.60656
# 7/7 [==============================] - 2s 254ms/step - loss: 0.5582 - accuracy: 0.7946 - val_loss: 0.7642 - val_accuracy: 0.8125 - lr: 1.0000e-04
# Epoch 13/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5895 - accuracy: 0.7946
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 13: val_loss did not improve from 0.60656
# 7/7 [==============================] - 2s 284ms/step - loss: 0.5895 - accuracy: 0.7946 - val_loss: 0.6242 - val_accuracy: 0.8438 - lr: 1.0000e-04
# Epoch 14/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4337 - accuracy: 0.8125
# Epoch 14: val_loss improved from 0.60656 to 0.48687, saving model to /content/gdrive/My Drive/data/VGG16model3.h5
# 7/7 [==============================] - 3s 381ms/step - loss: 0.4337 - accuracy: 0.8125 - val_loss: 0.4869 - val_accuracy: 0.8438 - lr: 5.0000e-05
# Epoch 15/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4977 - accuracy: 0.8125
# Epoch 15: val_loss did not improve from 0.48687
# 7/7 [==============================] - 3s 413ms/step - loss: 0.4977 - accuracy: 0.8125 - val_loss: 0.5024 - val_accuracy: 0.8438 - lr: 5.0000e-05
# Epoch 16/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3332 - accuracy: 0.8750
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 16: val_loss did not improve from 0.48687
# 7/7 [==============================] - 2s 283ms/step - loss: 0.3332 - accuracy: 0.8750 - val_loss: 0.5058 - val_accuracy: 0.8438 - lr: 5.0000e-05
# Epoch 17/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4187 - accuracy: 0.8482
# Epoch 17: val_loss improved from 0.48687 to 0.48622, saving model to /content/gdrive/My Drive/data/VGG16model3.h5
# 7/7 [==============================] - 3s 495ms/step - loss: 0.4187 - accuracy: 0.8482 - val_loss: 0.4862 - val_accuracy: 0.9062 - lr: 2.5000e-05
# Epoch 18/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3366 - accuracy: 0.8750
# Epoch 18: val_loss did not improve from 0.48622
# 7/7 [==============================] - 2s 283ms/step - loss: 0.3366 - accuracy: 0.8750 - val_loss: 0.5277 - val_accuracy: 0.8750 - lr: 2.5000e-05
# Epoch 19/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3088 - accuracy: 0.8929
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 19: val_loss did not improve from 0.48622
# 7/7 [==============================] - 2s 308ms/step - loss: 0.3088 - accuracy: 0.8929 - val_loss: 0.5327 - val_accuracy: 0.8750 - lr: 2.5000e-05
# Epoch 20/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3527 - accuracy: 0.8929
# Epoch 20: val_loss did not improve from 0.48622
# 7/7 [==============================] - 3s 434ms/step - loss: 0.3527 - accuracy: 0.8929 - val_loss: 0.5339 - val_accuracy: 0.8750 - lr: 1.2500e-05
# Epoch 21/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3604 - accuracy: 0.8482
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 21: val_loss did not improve from 0.48622
# 7/7 [==============================] - 2s 294ms/step - loss: 0.3604 - accuracy: 0.8482 - val_loss: 0.5484 - val_accuracy: 0.8750 - lr: 1.2500e-05
# Epoch 22/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2667 - accuracy: 0.9464
# Epoch 22: val_loss did not improve from 0.48622
# 7/7 [==============================] - 2s 288ms/step - loss: 0.2667 - accuracy: 0.9464 - val_loss: 0.5499 - val_accuracy: 0.8750 - lr: 6.2500e-06
# Epoch 22: early stopping
# 1/1 [==============================] - 0s 142ms/step
# fold 2 MAE: 0.25
# Epoch 1/50
# 7/7 [==============================] - ETA: 0s - loss: 1.6986 - accuracy: 0.2054
# Epoch 1: val_loss improved from inf to 1.67402, saving model to /content/gdrive/My Drive/data/VGG16model4.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7/7 [==============================] - 18s 2s/step - loss: 1.6986 - accuracy: 0.2054 - val_loss: 1.6740 - val_accuracy: 0.1875 - lr: 2.0000e-04
# Epoch 2/50
# 7/7 [==============================] - ETA: 0s - loss: 1.5742 - accuracy: 0.3125
# Epoch 2: val_loss improved from 1.67402 to 1.48378, saving model to /content/gdrive/My Drive/data/VGG16model4.h5
# 7/7 [==============================] - 2s 335ms/step - loss: 1.5742 - accuracy: 0.3125 - val_loss: 1.4838 - val_accuracy: 0.3750 - lr: 2.0000e-04
# Epoch 3/50
# 7/7 [==============================] - ETA: 0s - loss: 1.4387 - accuracy: 0.3929
# Epoch 3: val_loss improved from 1.48378 to 1.28565, saving model to /content/gdrive/My Drive/data/VGG16model4.h5
# 7/7 [==============================] - 3s 463ms/step - loss: 1.4387 - accuracy: 0.3929 - val_loss: 1.2856 - val_accuracy: 0.3750 - lr: 2.0000e-04
# Epoch 4/50
# 7/7 [==============================] - ETA: 0s - loss: 1.1380 - accuracy: 0.4732
# Epoch 4: val_loss did not improve from 1.28565
# 7/7 [==============================] - 3s 420ms/step - loss: 1.1380 - accuracy: 0.4732 - val_loss: 1.3068 - val_accuracy: 0.4062 - lr: 2.0000e-04
# Epoch 5/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0597 - accuracy: 0.5268
# Epoch 5: val_loss improved from 1.28565 to 1.23830, saving model to /content/gdrive/My Drive/data/VGG16model4.h5
# 7/7 [==============================] - 3s 403ms/step - loss: 1.0597 - accuracy: 0.5268 - val_loss: 1.2383 - val_accuracy: 0.6250 - lr: 2.0000e-04
# Epoch 6/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9156 - accuracy: 0.5893
# Epoch 6: val_loss did not improve from 1.23830
# 7/7 [==============================] - 2s 297ms/step - loss: 0.9156 - accuracy: 0.5893 - val_loss: 1.3260 - val_accuracy: 0.5625 - lr: 2.0000e-04
# Epoch 7/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8896 - accuracy: 0.6071
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
#
# Epoch 7: val_loss did not improve from 1.23830
# 7/7 [==============================] - 2s 362ms/step - loss: 0.8896 - accuracy: 0.6071 - val_loss: 1.3654 - val_accuracy: 0.5625 - lr: 2.0000e-04
# Epoch 8/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7995 - accuracy: 0.7054
# Epoch 8: val_loss improved from 1.23830 to 0.78917, saving model to /content/gdrive/My Drive/data/VGG16model4.h5
# 7/7 [==============================] - 3s 480ms/step - loss: 0.7995 - accuracy: 0.7054 - val_loss: 0.7892 - val_accuracy: 0.6562 - lr: 1.0000e-04
# Epoch 9/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7551 - accuracy: 0.6786
# Epoch 9: val_loss improved from 0.78917 to 0.76743, saving model to /content/gdrive/My Drive/data/VGG16model4.h5
# 7/7 [==============================] - 2s 359ms/step - loss: 0.7551 - accuracy: 0.6786 - val_loss: 0.7674 - val_accuracy: 0.6875 - lr: 1.0000e-04
# Epoch 10/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6592 - accuracy: 0.7054
# Epoch 10: val_loss did not improve from 0.76743
# 7/7 [==============================] - 2s 285ms/step - loss: 0.6592 - accuracy: 0.7054 - val_loss: 0.8893 - val_accuracy: 0.6875 - lr: 1.0000e-04
# Epoch 11/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6680 - accuracy: 0.7411
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 11: val_loss did not improve from 0.76743
# 7/7 [==============================] - 2s 265ms/step - loss: 0.6680 - accuracy: 0.7411 - val_loss: 0.7886 - val_accuracy: 0.6562 - lr: 1.0000e-04
# Epoch 12/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5767 - accuracy: 0.7500
# Epoch 12: val_loss did not improve from 0.76743
# 7/7 [==============================] - 3s 380ms/step - loss: 0.5767 - accuracy: 0.7500 - val_loss: 0.7904 - val_accuracy: 0.6875 - lr: 5.0000e-05
# Epoch 13/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5236 - accuracy: 0.7946
# Epoch 13: val_loss improved from 0.76743 to 0.72859, saving model to /content/gdrive/My Drive/data/VGG16model4.h5
# 7/7 [==============================] - 3s 394ms/step - loss: 0.5236 - accuracy: 0.7946 - val_loss: 0.7286 - val_accuracy: 0.6875 - lr: 5.0000e-05
# Epoch 14/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5543 - accuracy: 0.8304
# Epoch 14: val_loss improved from 0.72859 to 0.63002, saving model to /content/gdrive/My Drive/data/VGG16model4.h5
# 7/7 [==============================] - 2s 350ms/step - loss: 0.5543 - accuracy: 0.8304 - val_loss: 0.6300 - val_accuracy: 0.7188 - lr: 5.0000e-05
# Epoch 15/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5250 - accuracy: 0.7589
# Epoch 15: val_loss did not improve from 0.63002
# 7/7 [==============================] - 2s 333ms/step - loss: 0.5250 - accuracy: 0.7589 - val_loss: 0.8979 - val_accuracy: 0.7188 - lr: 5.0000e-05
# Epoch 16/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5475 - accuracy: 0.7946
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 16: val_loss did not improve from 0.63002
# 7/7 [==============================] - 3s 394ms/step - loss: 0.5475 - accuracy: 0.7946 - val_loss: 0.7386 - val_accuracy: 0.7188 - lr: 5.0000e-05
# Epoch 17/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7275 - accuracy: 0.7500
# Epoch 17: val_loss did not improve from 0.63002
# 7/7 [==============================] - 2s 337ms/step - loss: 0.7275 - accuracy: 0.7500 - val_loss: 0.7069 - val_accuracy: 0.6875 - lr: 2.5000e-05
# Epoch 18/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4378 - accuracy: 0.8304
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 18: val_loss did not improve from 0.63002
# 7/7 [==============================] - 2s 284ms/step - loss: 0.4378 - accuracy: 0.8304 - val_loss: 0.7853 - val_accuracy: 0.6875 - lr: 2.5000e-05
# Epoch 19/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4716 - accuracy: 0.8571
# Epoch 19: val_loss did not improve from 0.63002
# 7/7 [==============================] - 2s 287ms/step - loss: 0.4716 - accuracy: 0.8571 - val_loss: 0.7919 - val_accuracy: 0.6875 - lr: 1.2500e-05
# Epoch 19: early stopping
# 1/1 [==============================] - 0s 166ms/step
# fold 3 MAE: 0.22499999403953552
# Epoch 1/50
# 7/7 [==============================] - ETA: 0s - loss: 1.6001 - accuracy: 0.2946
# Epoch 1: val_loss improved from inf to 1.49006, saving model to /content/gdrive/My Drive/data/VGG16model5.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7/7 [==============================] - 17s 2s/step - loss: 1.6001 - accuracy: 0.2946 - val_loss: 1.4901 - val_accuracy: 0.3438 - lr: 2.0000e-04
# Epoch 2/50
# 7/7 [==============================] - ETA: 0s - loss: 1.5957 - accuracy: 0.2589
# Epoch 2: val_loss improved from 1.49006 to 1.37640, saving model to /content/gdrive/My Drive/data/VGG16model5.h5
# 7/7 [==============================] - 2s 341ms/step - loss: 1.5957 - accuracy: 0.2589 - val_loss: 1.3764 - val_accuracy: 0.4062 - lr: 2.0000e-04
# Epoch 3/50
# 7/7 [==============================] - ETA: 0s - loss: 1.3999 - accuracy: 0.3929
# Epoch 3: val_loss improved from 1.37640 to 1.24728, saving model to /content/gdrive/My Drive/data/VGG16model5.h5
# 7/7 [==============================] - 2s 345ms/step - loss: 1.3999 - accuracy: 0.3929 - val_loss: 1.2473 - val_accuracy: 0.3750 - lr: 2.0000e-04
# Epoch 4/50
# 7/7 [==============================] - ETA: 0s - loss: 1.2750 - accuracy: 0.4554
# Epoch 4: val_loss improved from 1.24728 to 0.86238, saving model to /content/gdrive/My Drive/data/VGG16model5.h5
# 7/7 [==============================] - 3s 468ms/step - loss: 1.2750 - accuracy: 0.4554 - val_loss: 0.8624 - val_accuracy: 0.6562 - lr: 2.0000e-04
# Epoch 5/50
# 7/7 [==============================] - ETA: 0s - loss: 1.1919 - accuracy: 0.4821
# Epoch 5: val_loss improved from 0.86238 to 0.83642, saving model to /content/gdrive/My Drive/data/VGG16model5.h5
# 7/7 [==============================] - 3s 386ms/step - loss: 1.1919 - accuracy: 0.4821 - val_loss: 0.8364 - val_accuracy: 0.5312 - lr: 2.0000e-04
# Epoch 6/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9999 - accuracy: 0.5446
# Epoch 6: val_loss did not improve from 0.83642
# 7/7 [==============================] - 2s 291ms/step - loss: 0.9999 - accuracy: 0.5446 - val_loss: 1.1163 - val_accuracy: 0.4688 - lr: 2.0000e-04
# Epoch 7/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8786 - accuracy: 0.6250
# Epoch 7: val_loss improved from 0.83642 to 0.77546, saving model to /content/gdrive/My Drive/data/VGG16model5.h5
# 7/7 [==============================] - 2s 344ms/step - loss: 0.8786 - accuracy: 0.6250 - val_loss: 0.7755 - val_accuracy: 0.6562 - lr: 2.0000e-04
# Epoch 8/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7652 - accuracy: 0.6696
# Epoch 8: val_loss did not improve from 0.77546
# 7/7 [==============================] - 2s 288ms/step - loss: 0.7652 - accuracy: 0.6696 - val_loss: 0.7902 - val_accuracy: 0.7188 - lr: 2.0000e-04
# Epoch 9/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8095 - accuracy: 0.6696
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
#
# Epoch 9: val_loss did not improve from 0.77546
# 7/7 [==============================] - 2s 300ms/step - loss: 0.8095 - accuracy: 0.6696 - val_loss: 0.9191 - val_accuracy: 0.6875 - lr: 2.0000e-04
# Epoch 10/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6236 - accuracy: 0.7411
# Epoch 10: val_loss improved from 0.77546 to 0.56534, saving model to /content/gdrive/My Drive/data/VGG16model5.h5
# 7/7 [==============================] - 3s 474ms/step - loss: 0.6236 - accuracy: 0.7411 - val_loss: 0.5653 - val_accuracy: 0.7188 - lr: 1.0000e-04
# Epoch 11/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5649 - accuracy: 0.7143
# Epoch 11: val_loss did not improve from 0.56534
# 7/7 [==============================] - 2s 290ms/step - loss: 0.5649 - accuracy: 0.7143 - val_loss: 0.6870 - val_accuracy: 0.7188 - lr: 1.0000e-04
# Epoch 12/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6039 - accuracy: 0.7589
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 12: val_loss did not improve from 0.56534
# 7/7 [==============================] - 2s 294ms/step - loss: 0.6039 - accuracy: 0.7589 - val_loss: 0.5756 - val_accuracy: 0.7812 - lr: 1.0000e-04
# Epoch 13/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4401 - accuracy: 0.8214
# Epoch 13: val_loss improved from 0.56534 to 0.54417, saving model to /content/gdrive/My Drive/data/VGG16model5.h5
# 7/7 [==============================] - 3s 424ms/step - loss: 0.4401 - accuracy: 0.8214 - val_loss: 0.5442 - val_accuracy: 0.6875 - lr: 5.0000e-05
# Epoch 14/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4577 - accuracy: 0.8036
# Epoch 14: val_loss did not improve from 0.54417
# 7/7 [==============================] - 3s 441ms/step - loss: 0.4577 - accuracy: 0.8036 - val_loss: 0.5582 - val_accuracy: 0.7188 - lr: 5.0000e-05
# Epoch 15/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4966 - accuracy: 0.7768
# Epoch 15: val_loss improved from 0.54417 to 0.50115, saving model to /content/gdrive/My Drive/data/VGG16model5.h5
# 7/7 [==============================] - 2s 350ms/step - loss: 0.4966 - accuracy: 0.7768 - val_loss: 0.5011 - val_accuracy: 0.7500 - lr: 5.0000e-05
# Epoch 16/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4601 - accuracy: 0.8125
# Epoch 16: val_loss improved from 0.50115 to 0.49270, saving model to /content/gdrive/My Drive/data/VGG16model5.h5
# 7/7 [==============================] - 2s 349ms/step - loss: 0.4601 - accuracy: 0.8125 - val_loss: 0.4927 - val_accuracy: 0.8125 - lr: 5.0000e-05
# Epoch 17/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3884 - accuracy: 0.8661
# Epoch 17: val_loss did not improve from 0.49270
# 7/7 [==============================] - 2s 290ms/step - loss: 0.3884 - accuracy: 0.8661 - val_loss: 0.5316 - val_accuracy: 0.7500 - lr: 5.0000e-05
# Epoch 18/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4017 - accuracy: 0.8393
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 18: val_loss did not improve from 0.49270
# 7/7 [==============================] - 2s 284ms/step - loss: 0.4017 - accuracy: 0.8393 - val_loss: 0.5273 - val_accuracy: 0.7812 - lr: 5.0000e-05
# Epoch 19/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3454 - accuracy: 0.8929
# Epoch 19: val_loss improved from 0.49270 to 0.48613, saving model to /content/gdrive/My Drive/data/VGG16model5.h5
# 7/7 [==============================] - 3s 473ms/step - loss: 0.3454 - accuracy: 0.8929 - val_loss: 0.4861 - val_accuracy: 0.7812 - lr: 2.5000e-05
# Epoch 20/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4090 - accuracy: 0.8482
# Epoch 20: val_loss did not improve from 0.48613
# 7/7 [==============================] - 2s 291ms/step - loss: 0.4090 - accuracy: 0.8482 - val_loss: 0.4992 - val_accuracy: 0.7812 - lr: 2.5000e-05
# Epoch 21/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4850 - accuracy: 0.8036
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 21: val_loss did not improve from 0.48613
# 7/7 [==============================] - 2s 287ms/step - loss: 0.4850 - accuracy: 0.8036 - val_loss: 0.5012 - val_accuracy: 0.7812 - lr: 2.5000e-05
# Epoch 22/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4641 - accuracy: 0.7946
# Epoch 22: val_loss did not improve from 0.48613
# 7/7 [==============================] - 2s 294ms/step - loss: 0.4641 - accuracy: 0.7946 - val_loss: 0.4915 - val_accuracy: 0.7500 - lr: 1.2500e-05
# Epoch 23/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3227 - accuracy: 0.8482
# Epoch 23: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 23: val_loss did not improve from 0.48613
# 7/7 [==============================] - 2s 326ms/step - loss: 0.3227 - accuracy: 0.8482 - val_loss: 0.4903 - val_accuracy: 0.7812 - lr: 1.2500e-05
# Epoch 24/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4226 - accuracy: 0.8214
# Epoch 24: val_loss did not improve from 0.48613
# 7/7 [==============================] - 3s 411ms/step - loss: 0.4226 - accuracy: 0.8214 - val_loss: 0.4926 - val_accuracy: 0.7812 - lr: 6.2500e-06
# Epoch 24: early stopping
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7e12e02863b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 152ms/step
# fold 4 MAE: 0.26249998807907104
# CV score: 0.2377438098192215
