# %%
# googledrive の使用
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import glob
import os

import numpy as np
from keras.applications.vgg16 import VGG16
from keras.callbacks import (CSVLogger, EarlyStopping, ModelCheckpoint, ReduceLROnPlateau)
from keras.layers import Dense, Dropout, GlobalAveragePooling2D, Input
from keras.models import Model
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
from PIL import Image, ImageOps
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt

# 画像データ（種類ごとにフォルダに格納）と出力ファイル（.h5など）のフォルダ指定
# GoogleColaboratoryで動かす場合の設定例
# 画像ファイルは、fractureの下にDimple、Rock、Striationなどのカテゴリ名を付けたフォルダに格納
data_path = '/content/gdrive/My Drive/data/fracture'
output_path = '/content/gdrive/My Drive/data'

# ローカルパソコンで動かす場合の設定例
# 画像ファイルは、fractureの下にDimple、Rock、Striationなどのカテゴリ名を付けたフォルダに格納
# data_path = "c:/data/fracture"
# output_path = "c:/data"

IMAGE_SIZE = 224 # 画像サイズ（ここでは使用するモデルの最大サイズを指定）
BATCH_SIZE = 16 # バッチサイズ
NB_EPOCH = 50 # 学習の最大回数
FOLD = 5 # 交差検証の回数

# ラベル名
# fractureの下のフォルダ名をラベル名とする（フォルダ名は全角文字不可）
labels = os.listdir(data_path)
print(labels)

# ラベル数
nb_classes = len(labels)
print(nb_classes)

# モデルの構築
def build_model():

    input_tensor = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
    base_model = VGG16(weights='imagenet', include_top=False, input_tensor=input_tensor)

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.20)(x) # 0.20の値は適宜変更
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.20)(x) # 0.20の値は適宜変更
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.20)(x) # 0.20の値は適宜変更
    predictions = Dense(nb_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)

    # ファインチューニング
    for layer in model.layers[:15]:
        layer.trainable = False
    for layer in model.layers[15:]:
        layer.trainable = True

    # ラベルデータの整数値を2値クラスの行列とするため、loss='categorical_crossentropy'を使う
    model.compile(optimizer=Adam(learning_rate=0.0002), loss='categorical_crossentropy', metrics=['accuracy']) # learning_rateは適宜調整

    return model

# データの初期化
X = []
y = []

# データの読み込み
for index, name in enumerate(labels):
    data_dir = data_path + '/' + name
    data_files = glob.glob(data_dir + "/*.*")
    for i, data_file in enumerate(data_files):

        image = Image.open(data_file)
        image = image.convert("RGB")

        im = ImageOps.fit(
            image, (IMAGE_SIZE, IMAGE_SIZE), Image.Resampling.LANCZOS
        )
        data = np.asarray(im)
        X.append(data)
        y.append(index)

X = np.array(X)
y = np.array(y)

data_num = len(X)
steps_per_epoch = data_num * (7 / 10) / BATCH_SIZE
print(steps_per_epoch)

valid_scores = []
models = []

# 交差検証
kf = KFold(n_splits=FOLD, shuffle=True, random_state=42)
for fold, (train_indices, valid_indices) in enumerate(kf.split(X)):

    # 学習データと検証データに分ける
    X_train, X_valid = X[train_indices], X[valid_indices]
    y_train, y_valid = y[train_indices], y[valid_indices]

    # ラベルデータの整数値を2値クラスの行列に変換（例 2番目のラベルを「0,1,0,0,0」と表現）
    y_train = to_categorical(y_train, nb_classes)
    y_valid = to_categorical(y_valid, nb_classes)

    # モデルの呼び出し
    model = build_model()

    # 学習用画像のアレンジの仕方を定義
    train_datagen = ImageDataGenerator(
        rescale=1.0 / 255, # 画素値の正規化（0～255を0～1に）
        # 水増しの条件は適宜変更
        width_shift_range=0.1,
        height_shift_range=0.1,
        rotation_range=30,
        channel_shift_range=50,
        brightness_range=[0.3, 1.0],
        horizontal_flip=True,
        vertical_flip=True,
    )

    # アレンジした学習用画像生成
    train_datagen.fit(X_train)

    # 検証用画像の生成（正規化のみ実行）
    valid_datagen = ImageDataGenerator(rescale=1.0 / 255) # 画素値の正規化（0～255を0～1に）
    valid_datagen.fit(X_valid)

    # 学習結果のファイル名定義
    ResultFileName = output_path + '/' + 'VGG16model' + str(fold+1)

    # 学習経過のファイル名定義
    csv_log = CSVLogger(
        ResultFileName + '.csv'
    )

    # 学習終了の条件定義
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=5,
        verbose=1
    )

    # 学習率の更新条件定義
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=2,
        verbose=1
    )

    # モデルの重みを一定頻度で保存
    modelCheckpoint = ModelCheckpoint(
        filepath = ResultFileName + '.h5',
        monitor='val_loss',
        verbose=1,
        save_best_only=True,
        save_weights_only=False,
        mode='min',
        save_freq='epoch'
    )

    # 学習
    history = model.fit(
        train_datagen.flow(X_train, y_train, batch_size = BATCH_SIZE),
        epochs = NB_EPOCH,
        steps_per_epoch = steps_per_epoch,
        validation_steps = 1,
        verbose=1,
        validation_data = valid_datagen.flow(X_valid, y_valid),
        callbacks = [csv_log, early_stopping, reduce_lr, modelCheckpoint]
    )

    # 検証
    y_valid_pred = model.predict(X_valid)

    # MAEの計算
    score = mean_absolute_error(y_valid, y_valid_pred)
    print(f'fold {fold} MAE: {score}')
    valid_scores.append(score)
    models.append(model)

    # 学習結果のグラフ表示
    acc = history.history["accuracy"]
    val_acc = history.history["val_accuracy"]
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(len(acc))
    plt.plot(epochs, acc, "bo", label="Training")
    plt.plot(epochs, val_acc, "b", label="Validation")
    plt.title("Training and validation accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.figure()
    plt.plot(epochs, loss, "bo", label="Training")
    plt.plot(epochs, val_loss, "b", label="Validation")
    plt.title("Training and validation loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()


# MEAの平均値
cv_score = np.mean(valid_scores)
print(f'CV score: {cv_score}')
# Out:
# ['Rock', 'Fan-shaped', 'River', 'Dimple', 'Striation']
# 5
# 7.0
# Epoch 1/50
# 7/7 [==============================] - ETA: 0s - loss: 1.6322 - accuracy: 0.2054
# Epoch 1: val_loss improved from inf to 1.48149, saving model to /content/gdrive/My Drive/data/VGG16model1.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7/7 [==============================] - 7s 597ms/step - loss: 1.6322 - accuracy: 0.2054 - val_loss: 1.4815 - val_accuracy: 0.5312 - lr: 2.0000e-04
# Epoch 2/50
# 7/7 [==============================] - ETA: 0s - loss: 1.5541 - accuracy: 0.2768
# Epoch 2: val_loss improved from 1.48149 to 1.29022, saving model to /content/gdrive/My Drive/data/VGG16model1.h5
# 7/7 [==============================] - 2s 324ms/step - loss: 1.5541 - accuracy: 0.2768 - val_loss: 1.2902 - val_accuracy: 0.4688 - lr: 2.0000e-04
# Epoch 3/50
# 7/7 [==============================] - ETA: 0s - loss: 1.4110 - accuracy: 0.3571
# Epoch 3: val_loss improved from 1.29022 to 0.97537, saving model to /content/gdrive/My Drive/data/VGG16model1.h5
# 7/7 [==============================] - 2s 327ms/step - loss: 1.4110 - accuracy: 0.3571 - val_loss: 0.9754 - val_accuracy: 0.6250 - lr: 2.0000e-04
# Epoch 4/50
# 7/7 [==============================] - ETA: 0s - loss: 1.1872 - accuracy: 0.5000
# Epoch 4: val_loss did not improve from 0.97537
# 7/7 [==============================] - 2s 276ms/step - loss: 1.1872 - accuracy: 0.5000 - val_loss: 0.9913 - val_accuracy: 0.5938 - lr: 2.0000e-04
# Epoch 5/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0711 - accuracy: 0.5982
# Epoch 5: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
#
# Epoch 5: val_loss did not improve from 0.97537
# 7/7 [==============================] - 3s 380ms/step - loss: 1.0711 - accuracy: 0.5982 - val_loss: 1.1035 - val_accuracy: 0.5312 - lr: 2.0000e-04
# Epoch 6/50
# 7/7 [==============================] - ETA: 0s - loss: 1.1204 - accuracy: 0.5179
# Epoch 6: val_loss improved from 0.97537 to 0.90281, saving model to /content/gdrive/My Drive/data/VGG16model1.h5
# 7/7 [==============================] - 3s 389ms/step - loss: 1.1204 - accuracy: 0.5179 - val_loss: 0.9028 - val_accuracy: 0.6562 - lr: 1.0000e-04
# Epoch 7/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0257 - accuracy: 0.5268
# Epoch 7: val_loss improved from 0.90281 to 0.67340, saving model to /content/gdrive/My Drive/data/VGG16model1.h5
# 7/7 [==============================] - 2s 343ms/step - loss: 1.0257 - accuracy: 0.5268 - val_loss: 0.6734 - val_accuracy: 0.7188 - lr: 1.0000e-04
# Epoch 8/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9887 - accuracy: 0.6250
# Epoch 8: val_loss improved from 0.67340 to 0.65695, saving model to /content/gdrive/My Drive/data/VGG16model1.h5
# 7/7 [==============================] - 2s 344ms/step - loss: 0.9887 - accuracy: 0.6250 - val_loss: 0.6570 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 9/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8498 - accuracy: 0.7143
# Epoch 9: val_loss did not improve from 0.65695
# 7/7 [==============================] - 2s 335ms/step - loss: 0.8498 - accuracy: 0.7143 - val_loss: 0.7592 - val_accuracy: 0.6875 - lr: 1.0000e-04
# Epoch 10/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7405 - accuracy: 0.7054
# Epoch 10: val_loss improved from 0.65695 to 0.60596, saving model to /content/gdrive/My Drive/data/VGG16model1.h5
# 7/7 [==============================] - 3s 377ms/step - loss: 0.7405 - accuracy: 0.7054 - val_loss: 0.6060 - val_accuracy: 0.7188 - lr: 1.0000e-04
# Epoch 11/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6385 - accuracy: 0.7411
# Epoch 11: val_loss did not improve from 0.60596
# 7/7 [==============================] - 2s 278ms/step - loss: 0.6385 - accuracy: 0.7411 - val_loss: 0.7923 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 12/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6852 - accuracy: 0.7411
# Epoch 12: val_loss improved from 0.60596 to 0.31419, saving model to /content/gdrive/My Drive/data/VGG16model1.h5
# 7/7 [==============================] - 3s 436ms/step - loss: 0.6852 - accuracy: 0.7411 - val_loss: 0.3142 - val_accuracy: 0.9375 - lr: 1.0000e-04
# Epoch 13/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7941 - accuracy: 0.6786
# Epoch 13: val_loss did not improve from 0.31419
# 7/7 [==============================] - 2s 255ms/step - loss: 0.7941 - accuracy: 0.6786 - val_loss: 0.7727 - val_accuracy: 0.7812 - lr: 1.0000e-04
# Epoch 14/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6550 - accuracy: 0.7857
# Epoch 14: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 14: val_loss did not improve from 0.31419
# 7/7 [==============================] - 2s 276ms/step - loss: 0.6550 - accuracy: 0.7857 - val_loss: 0.4806 - val_accuracy: 0.7812 - lr: 1.0000e-04
# Epoch 15/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6371 - accuracy: 0.7946
# Epoch 15: val_loss did not improve from 0.31419
# 7/7 [==============================] - 3s 402ms/step - loss: 0.6371 - accuracy: 0.7946 - val_loss: 0.4659 - val_accuracy: 0.8438 - lr: 5.0000e-05
# Epoch 16/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4779 - accuracy: 0.8571
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 16: val_loss did not improve from 0.31419
# 7/7 [==============================] - 2s 279ms/step - loss: 0.4779 - accuracy: 0.8571 - val_loss: 0.4533 - val_accuracy: 0.8125 - lr: 5.0000e-05
# Epoch 17/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5432 - accuracy: 0.8214
# Epoch 17: val_loss did not improve from 0.31419
# 7/7 [==============================] - 2s 273ms/step - loss: 0.5432 - accuracy: 0.8214 - val_loss: 0.4147 - val_accuracy: 0.8125 - lr: 2.5000e-05
# Epoch 17: early stopping
# 1/1 [==============================] - 0s 153ms/step
# fold 0 MAE: 0.18750108778476715
# Epoch 1/50
# 7/7 [==============================] - ETA: 0s - loss: 1.6656 - accuracy: 0.2679
# Epoch 1: val_loss improved from inf to 1.58793, saving model to /content/gdrive/My Drive/data/VGG16model2.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7/7 [==============================] - 51s 538ms/step - loss: 1.6656 - accuracy: 0.2679 - val_loss: 1.5879 - val_accuracy: 0.2188 - lr: 2.0000e-04
# Epoch 2/50
# 7/7 [==============================] - ETA: 0s - loss: 1.5066 - accuracy: 0.3571
# Epoch 2: val_loss improved from 1.58793 to 1.34692, saving model to /content/gdrive/My Drive/data/VGG16model2.h5
# 7/7 [==============================] - 3s 369ms/step - loss: 1.5066 - accuracy: 0.3571 - val_loss: 1.3469 - val_accuracy: 0.3125 - lr: 2.0000e-04
# Epoch 3/50
# 7/7 [==============================] - ETA: 0s - loss: 1.4084 - accuracy: 0.3393
# Epoch 3: val_loss improved from 1.34692 to 1.30792, saving model to /content/gdrive/My Drive/data/VGG16model2.h5
# 7/7 [==============================] - 2s 356ms/step - loss: 1.4084 - accuracy: 0.3393 - val_loss: 1.3079 - val_accuracy: 0.3750 - lr: 2.0000e-04
# Epoch 4/50
# 7/7 [==============================] - ETA: 0s - loss: 1.1984 - accuracy: 0.4911
# Epoch 4: val_loss did not improve from 1.30792
# 7/7 [==============================] - 2s 276ms/step - loss: 1.1984 - accuracy: 0.4911 - val_loss: 1.4001 - val_accuracy: 0.4062 - lr: 2.0000e-04
# Epoch 5/50
# 7/7 [==============================] - ETA: 0s - loss: 1.2080 - accuracy: 0.5089
# Epoch 5: val_loss improved from 1.30792 to 1.08024, saving model to /content/gdrive/My Drive/data/VGG16model2.h5
# 7/7 [==============================] - 2s 371ms/step - loss: 1.2080 - accuracy: 0.5089 - val_loss: 1.0802 - val_accuracy: 0.5938 - lr: 2.0000e-04
# Epoch 6/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0366 - accuracy: 0.5446
# Epoch 6: val_loss did not improve from 1.08024
# 7/7 [==============================] - 3s 481ms/step - loss: 1.0366 - accuracy: 0.5446 - val_loss: 1.3658 - val_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 7/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9635 - accuracy: 0.6161
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
#
# Epoch 7: val_loss did not improve from 1.08024
# 7/7 [==============================] - 2s 266ms/step - loss: 0.9635 - accuracy: 0.6161 - val_loss: 1.3307 - val_accuracy: 0.5938 - lr: 2.0000e-04
# Epoch 8/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8182 - accuracy: 0.6696
# Epoch 8: val_loss improved from 1.08024 to 1.05272, saving model to /content/gdrive/My Drive/data/VGG16model2.h5
# 7/7 [==============================] - 2s 324ms/step - loss: 0.8182 - accuracy: 0.6696 - val_loss: 1.0527 - val_accuracy: 0.6562 - lr: 1.0000e-04
# Epoch 9/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7789 - accuracy: 0.6875
# Epoch 9: val_loss did not improve from 1.05272
# 7/7 [==============================] - 2s 277ms/step - loss: 0.7789 - accuracy: 0.6875 - val_loss: 1.2788 - val_accuracy: 0.7188 - lr: 1.0000e-04
# Epoch 10/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6793 - accuracy: 0.7500
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 10: val_loss did not improve from 1.05272
# 7/7 [==============================] - 2s 259ms/step - loss: 0.6793 - accuracy: 0.7500 - val_loss: 1.1481 - val_accuracy: 0.7188 - lr: 1.0000e-04
# Epoch 11/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6626 - accuracy: 0.7679
# Epoch 11: val_loss improved from 1.05272 to 0.98263, saving model to /content/gdrive/My Drive/data/VGG16model2.h5
# 7/7 [==============================] - 3s 528ms/step - loss: 0.6626 - accuracy: 0.7679 - val_loss: 0.9826 - val_accuracy: 0.7500 - lr: 5.0000e-05
# Epoch 12/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5904 - accuracy: 0.7232
# Epoch 12: val_loss did not improve from 0.98263
# 7/7 [==============================] - 2s 259ms/step - loss: 0.5904 - accuracy: 0.7232 - val_loss: 1.0666 - val_accuracy: 0.7188 - lr: 5.0000e-05
# Epoch 13/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5782 - accuracy: 0.7857
# Epoch 13: val_loss improved from 0.98263 to 0.86446, saving model to /content/gdrive/My Drive/data/VGG16model2.h5
# 7/7 [==============================] - 2s 343ms/step - loss: 0.5782 - accuracy: 0.7857 - val_loss: 0.8645 - val_accuracy: 0.7812 - lr: 5.0000e-05
# Epoch 14/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5439 - accuracy: 0.7232
# Epoch 14: val_loss did not improve from 0.86446
# 7/7 [==============================] - 2s 266ms/step - loss: 0.5439 - accuracy: 0.7232 - val_loss: 0.8957 - val_accuracy: 0.8125 - lr: 5.0000e-05
# Epoch 15/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5443 - accuracy: 0.7857
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 15: val_loss did not improve from 0.86446
# 7/7 [==============================] - 2s 280ms/step - loss: 0.5443 - accuracy: 0.7857 - val_loss: 0.9148 - val_accuracy: 0.8438 - lr: 5.0000e-05
# Epoch 16/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4781 - accuracy: 0.7946
# Epoch 16: val_loss did not improve from 0.86446
# 7/7 [==============================] - 3s 415ms/step - loss: 0.4781 - accuracy: 0.7946 - val_loss: 0.9376 - val_accuracy: 0.7500 - lr: 2.5000e-05
# Epoch 17/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5122 - accuracy: 0.8036
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 17: val_loss did not improve from 0.86446
# 7/7 [==============================] - 2s 260ms/step - loss: 0.5122 - accuracy: 0.8036 - val_loss: 1.0193 - val_accuracy: 0.7812 - lr: 2.5000e-05
# Epoch 18/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4882 - accuracy: 0.8125
# Epoch 18: val_loss did not improve from 0.86446
# 7/7 [==============================] - 2s 282ms/step - loss: 0.4882 - accuracy: 0.8125 - val_loss: 0.8923 - val_accuracy: 0.8438 - lr: 1.2500e-05
# Epoch 18: early stopping
# 1/1 [==============================] - 0s 147ms/step
# fold 1 MAE: 0.1875
# Epoch 1/50
# 7/7 [==============================] - ETA: 0s - loss: 1.6863 - accuracy: 0.1429
# Epoch 1: val_loss improved from inf to 1.47270, saving model to /content/gdrive/My Drive/data/VGG16model3.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7/7 [==============================] - 7s 658ms/step - loss: 1.6863 - accuracy: 0.1429 - val_loss: 1.4727 - val_accuracy: 0.3750 - lr: 2.0000e-04
# Epoch 2/50
# 7/7 [==============================] - ETA: 0s - loss: 1.4873 - accuracy: 0.3482
# Epoch 2: val_loss improved from 1.47270 to 1.20960, saving model to /content/gdrive/My Drive/data/VGG16model3.h5
# 7/7 [==============================] - 2s 350ms/step - loss: 1.4873 - accuracy: 0.3482 - val_loss: 1.2096 - val_accuracy: 0.5625 - lr: 2.0000e-04
# Epoch 3/50
# 7/7 [==============================] - ETA: 0s - loss: 1.4309 - accuracy: 0.3214
# Epoch 3: val_loss improved from 1.20960 to 1.04927, saving model to /content/gdrive/My Drive/data/VGG16model3.h5
# 7/7 [==============================] - 3s 372ms/step - loss: 1.4309 - accuracy: 0.3214 - val_loss: 1.0493 - val_accuracy: 0.5938 - lr: 2.0000e-04
# Epoch 4/50
# 7/7 [==============================] - ETA: 0s - loss: 1.1834 - accuracy: 0.5000
# Epoch 4: val_loss improved from 1.04927 to 0.93192, saving model to /content/gdrive/My Drive/data/VGG16model3.h5
# 7/7 [==============================] - 3s 394ms/step - loss: 1.1834 - accuracy: 0.5000 - val_loss: 0.9319 - val_accuracy: 0.5625 - lr: 2.0000e-04
# Epoch 5/50
# 7/7 [==============================] - ETA: 0s - loss: 1.1391 - accuracy: 0.5179
# Epoch 5: val_loss did not improve from 0.93192
# 7/7 [==============================] - 3s 402ms/step - loss: 1.1391 - accuracy: 0.5179 - val_loss: 1.2379 - val_accuracy: 0.5625 - lr: 2.0000e-04
# Epoch 6/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0253 - accuracy: 0.5446
# Epoch 6: val_loss improved from 0.93192 to 0.72748, saving model to /content/gdrive/My Drive/data/VGG16model3.h5
# 7/7 [==============================] - 3s 423ms/step - loss: 1.0253 - accuracy: 0.5446 - val_loss: 0.7275 - val_accuracy: 0.6875 - lr: 2.0000e-04
# Epoch 7/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7324 - accuracy: 0.7232
# Epoch 7: val_loss improved from 0.72748 to 0.65192, saving model to /content/gdrive/My Drive/data/VGG16model3.h5
# 7/7 [==============================] - 2s 354ms/step - loss: 0.7324 - accuracy: 0.7232 - val_loss: 0.6519 - val_accuracy: 0.7500 - lr: 2.0000e-04
# Epoch 8/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7350 - accuracy: 0.6339
# Epoch 8: val_loss did not improve from 0.65192
# 7/7 [==============================] - 2s 293ms/step - loss: 0.7350 - accuracy: 0.6339 - val_loss: 1.1716 - val_accuracy: 0.6250 - lr: 2.0000e-04
# Epoch 9/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7802 - accuracy: 0.6786
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
#
# Epoch 9: val_loss did not improve from 0.65192
# 7/7 [==============================] - 2s 299ms/step - loss: 0.7802 - accuracy: 0.6786 - val_loss: 0.9226 - val_accuracy: 0.6875 - lr: 2.0000e-04
# Epoch 10/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7191 - accuracy: 0.7232
# Epoch 10: val_loss did not improve from 0.65192
# 7/7 [==============================] - 3s 468ms/step - loss: 0.7191 - accuracy: 0.7232 - val_loss: 0.8302 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 11/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7084 - accuracy: 0.6696
# Epoch 11: val_loss improved from 0.65192 to 0.63713, saving model to /content/gdrive/My Drive/data/VGG16model3.h5
# 7/7 [==============================] - 3s 502ms/step - loss: 0.7084 - accuracy: 0.6696 - val_loss: 0.6371 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 12/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5655 - accuracy: 0.7321
# Epoch 12: val_loss did not improve from 0.63713
# 7/7 [==============================] - 2s 287ms/step - loss: 0.5655 - accuracy: 0.7321 - val_loss: 0.8377 - val_accuracy: 0.7188 - lr: 1.0000e-04
# Epoch 13/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5285 - accuracy: 0.7857
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 13: val_loss did not improve from 0.63713
# 7/7 [==============================] - 2s 297ms/step - loss: 0.5285 - accuracy: 0.7857 - val_loss: 0.6427 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 14/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4640 - accuracy: 0.8125
# Epoch 14: val_loss improved from 0.63713 to 0.56924, saving model to /content/gdrive/My Drive/data/VGG16model3.h5
# 7/7 [==============================] - 4s 546ms/step - loss: 0.4640 - accuracy: 0.8125 - val_loss: 0.5692 - val_accuracy: 0.7812 - lr: 5.0000e-05
# Epoch 15/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4221 - accuracy: 0.7679
# Epoch 15: val_loss did not improve from 0.56924
# 7/7 [==============================] - 2s 286ms/step - loss: 0.4221 - accuracy: 0.7679 - val_loss: 0.5977 - val_accuracy: 0.7812 - lr: 5.0000e-05
# Epoch 16/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3995 - accuracy: 0.8125
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 16: val_loss did not improve from 0.56924
# 7/7 [==============================] - 2s 271ms/step - loss: 0.3995 - accuracy: 0.8125 - val_loss: 0.6265 - val_accuracy: 0.8125 - lr: 5.0000e-05
# Epoch 17/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4426 - accuracy: 0.8482
# Epoch 17: val_loss did not improve from 0.56924
# 7/7 [==============================] - 2s 261ms/step - loss: 0.4426 - accuracy: 0.8482 - val_loss: 0.6501 - val_accuracy: 0.8125 - lr: 2.5000e-05
# Epoch 18/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3911 - accuracy: 0.8482
# Epoch 18: val_loss improved from 0.56924 to 0.54576, saving model to /content/gdrive/My Drive/data/VGG16model3.h5
# 7/7 [==============================] - 3s 379ms/step - loss: 0.3911 - accuracy: 0.8482 - val_loss: 0.5458 - val_accuracy: 0.8438 - lr: 2.5000e-05
# Epoch 19/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3374 - accuracy: 0.8393
# Epoch 19: val_loss improved from 0.54576 to 0.54128, saving model to /content/gdrive/My Drive/data/VGG16model3.h5
# 7/7 [==============================] - 4s 551ms/step - loss: 0.3374 - accuracy: 0.8393 - val_loss: 0.5413 - val_accuracy: 0.8125 - lr: 2.5000e-05
# Epoch 20/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4010 - accuracy: 0.8661
# Epoch 20: val_loss did not improve from 0.54128
# 7/7 [==============================] - 2s 280ms/step - loss: 0.4010 - accuracy: 0.8661 - val_loss: 0.5931 - val_accuracy: 0.8125 - lr: 2.5000e-05
# Epoch 21/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3075 - accuracy: 0.8839
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 21: val_loss did not improve from 0.54128
# 7/7 [==============================] - 2s 258ms/step - loss: 0.3075 - accuracy: 0.8839 - val_loss: 0.6235 - val_accuracy: 0.8438 - lr: 2.5000e-05
# Epoch 22/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3616 - accuracy: 0.8393
# Epoch 22: val_loss did not improve from 0.54128
# 7/7 [==============================] - 2s 293ms/step - loss: 0.3616 - accuracy: 0.8393 - val_loss: 0.5871 - val_accuracy: 0.8125 - lr: 1.2500e-05
# Epoch 23/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3603 - accuracy: 0.8393
# Epoch 23: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 23: val_loss did not improve from 0.54128
# 7/7 [==============================] - 2s 313ms/step - loss: 0.3603 - accuracy: 0.8393 - val_loss: 0.5779 - val_accuracy: 0.8125 - lr: 1.2500e-05
# Epoch 24/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4132 - accuracy: 0.8125
# Epoch 24: val_loss did not improve from 0.54128
# 7/7 [==============================] - 2s 362ms/step - loss: 0.4132 - accuracy: 0.8125 - val_loss: 0.5606 - val_accuracy: 0.8125 - lr: 6.2500e-06
# Epoch 24: early stopping
# 1/1 [==============================] - 0s 243ms/step
# fold 2 MAE: 0.25
# Epoch 1/50
# 7/7 [==============================] - ETA: 0s - loss: 1.5821 - accuracy: 0.2679
# Epoch 1: val_loss improved from inf to 1.49000, saving model to /content/gdrive/My Drive/data/VGG16model4.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7/7 [==============================] - 6s 498ms/step - loss: 1.5821 - accuracy: 0.2679 - val_loss: 1.4900 - val_accuracy: 0.4688 - lr: 2.0000e-04
# Epoch 2/50
# 7/7 [==============================] - ETA: 0s - loss: 1.3447 - accuracy: 0.4107
# Epoch 2: val_loss improved from 1.49000 to 1.16514, saving model to /content/gdrive/My Drive/data/VGG16model4.h5
# 7/7 [==============================] - 3s 523ms/step - loss: 1.3447 - accuracy: 0.4107 - val_loss: 1.1651 - val_accuracy: 0.4062 - lr: 2.0000e-04
# Epoch 3/50
# 7/7 [==============================] - ETA: 0s - loss: 1.2854 - accuracy: 0.5000
# Epoch 3: val_loss improved from 1.16514 to 1.00457, saving model to /content/gdrive/My Drive/data/VGG16model4.h5
# 7/7 [==============================] - 4s 510ms/step - loss: 1.2854 - accuracy: 0.5000 - val_loss: 1.0046 - val_accuracy: 0.5625 - lr: 2.0000e-04
# Epoch 4/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0685 - accuracy: 0.5536
# Epoch 4: val_loss improved from 1.00457 to 0.94773, saving model to /content/gdrive/My Drive/data/VGG16model4.h5
# 7/7 [==============================] - 3s 374ms/step - loss: 1.0685 - accuracy: 0.5536 - val_loss: 0.9477 - val_accuracy: 0.5312 - lr: 2.0000e-04
# Epoch 5/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0181 - accuracy: 0.5446
# Epoch 5: val_loss improved from 0.94773 to 0.91124, saving model to /content/gdrive/My Drive/data/VGG16model4.h5
# 7/7 [==============================] - 3s 386ms/step - loss: 1.0181 - accuracy: 0.5446 - val_loss: 0.9112 - val_accuracy: 0.5938 - lr: 2.0000e-04
# Epoch 6/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8151 - accuracy: 0.6964
# Epoch 6: val_loss did not improve from 0.91124
# 7/7 [==============================] - 3s 411ms/step - loss: 0.8151 - accuracy: 0.6964 - val_loss: 1.0002 - val_accuracy: 0.5938 - lr: 2.0000e-04
# Epoch 7/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8429 - accuracy: 0.6161
# Epoch 7: val_loss improved from 0.91124 to 0.61666, saving model to /content/gdrive/My Drive/data/VGG16model4.h5
# 7/7 [==============================] - 3s 400ms/step - loss: 0.8429 - accuracy: 0.6161 - val_loss: 0.6167 - val_accuracy: 0.7812 - lr: 2.0000e-04
# Epoch 8/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6730 - accuracy: 0.6875
# Epoch 8: val_loss did not improve from 0.61666
# 7/7 [==============================] - 2s 262ms/step - loss: 0.6730 - accuracy: 0.6875 - val_loss: 0.6622 - val_accuracy: 0.7500 - lr: 2.0000e-04
# Epoch 9/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5944 - accuracy: 0.7679
# Epoch 9: val_loss improved from 0.61666 to 0.49015, saving model to /content/gdrive/My Drive/data/VGG16model4.h5
# 7/7 [==============================] - 2s 353ms/step - loss: 0.5944 - accuracy: 0.7679 - val_loss: 0.4901 - val_accuracy: 0.8438 - lr: 2.0000e-04
# Epoch 10/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5820 - accuracy: 0.7857
# Epoch 10: val_loss did not improve from 0.49015
# 7/7 [==============================] - 3s 381ms/step - loss: 0.5820 - accuracy: 0.7857 - val_loss: 0.7331 - val_accuracy: 0.6250 - lr: 2.0000e-04
# Epoch 11/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5745 - accuracy: 0.7589
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
#
# Epoch 11: val_loss did not improve from 0.49015
# 7/7 [==============================] - 2s 318ms/step - loss: 0.5745 - accuracy: 0.7589 - val_loss: 0.4964 - val_accuracy: 0.8125 - lr: 2.0000e-04
# Epoch 12/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5158 - accuracy: 0.8125
# Epoch 12: val_loss improved from 0.49015 to 0.45035, saving model to /content/gdrive/My Drive/data/VGG16model4.h5
# 7/7 [==============================] - 3s 388ms/step - loss: 0.5158 - accuracy: 0.8125 - val_loss: 0.4503 - val_accuracy: 0.8125 - lr: 1.0000e-04
# Epoch 13/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4569 - accuracy: 0.7946
# Epoch 13: val_loss did not improve from 0.45035
# 7/7 [==============================] - 2s 284ms/step - loss: 0.4569 - accuracy: 0.7946 - val_loss: 0.5742 - val_accuracy: 0.7188 - lr: 1.0000e-04
# Epoch 14/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4512 - accuracy: 0.8214
# Epoch 14: val_loss improved from 0.45035 to 0.43740, saving model to /content/gdrive/My Drive/data/VGG16model4.h5
# 7/7 [==============================] - 2s 362ms/step - loss: 0.4512 - accuracy: 0.8214 - val_loss: 0.4374 - val_accuracy: 0.8125 - lr: 1.0000e-04
# Epoch 15/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3245 - accuracy: 0.8571
# Epoch 15: val_loss did not improve from 0.43740
# 7/7 [==============================] - 2s 339ms/step - loss: 0.3245 - accuracy: 0.8571 - val_loss: 0.5110 - val_accuracy: 0.8438 - lr: 1.0000e-04
# Epoch 16/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2793 - accuracy: 0.8839
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 16: val_loss did not improve from 0.43740
# 7/7 [==============================] - 3s 344ms/step - loss: 0.2793 - accuracy: 0.8839 - val_loss: 0.7760 - val_accuracy: 0.7812 - lr: 1.0000e-04
# Epoch 17/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3267 - accuracy: 0.8839
# Epoch 17: val_loss did not improve from 0.43740
# 7/7 [==============================] - 2s 256ms/step - loss: 0.3267 - accuracy: 0.8839 - val_loss: 0.5064 - val_accuracy: 0.8438 - lr: 5.0000e-05
# Epoch 18/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2679 - accuracy: 0.9196
# Epoch 18: val_loss improved from 0.43740 to 0.42468, saving model to /content/gdrive/My Drive/data/VGG16model4.h5
# 7/7 [==============================] - 2s 363ms/step - loss: 0.2679 - accuracy: 0.9196 - val_loss: 0.4247 - val_accuracy: 0.9062 - lr: 5.0000e-05
# Epoch 19/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3065 - accuracy: 0.8929
# Epoch 19: val_loss did not improve from 0.42468
# 7/7 [==============================] - 2s 280ms/step - loss: 0.3065 - accuracy: 0.8929 - val_loss: 0.4444 - val_accuracy: 0.8438 - lr: 5.0000e-05
# Epoch 20/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2657 - accuracy: 0.9018
# Epoch 20: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 20: val_loss did not improve from 0.42468
# 7/7 [==============================] - 2s 298ms/step - loss: 0.2657 - accuracy: 0.9018 - val_loss: 0.4948 - val_accuracy: 0.8750 - lr: 5.0000e-05
# Epoch 21/50
# 7/7 [==============================] - ETA: 0s - loss: 0.1933 - accuracy: 0.9196
# Epoch 21: val_loss did not improve from 0.42468
# 7/7 [==============================] - 3s 380ms/step - loss: 0.1933 - accuracy: 0.9196 - val_loss: 0.5271 - val_accuracy: 0.8438 - lr: 2.5000e-05
# Epoch 22/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2767 - accuracy: 0.8929
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 22: val_loss did not improve from 0.42468
# 7/7 [==============================] - 2s 300ms/step - loss: 0.2767 - accuracy: 0.8929 - val_loss: 0.5477 - val_accuracy: 0.8125 - lr: 2.5000e-05
# Epoch 23/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2506 - accuracy: 0.9018
# Epoch 23: val_loss did not improve from 0.42468
# 7/7 [==============================] - 2s 291ms/step - loss: 0.2506 - accuracy: 0.9018 - val_loss: 0.5132 - val_accuracy: 0.8125 - lr: 1.2500e-05
# Epoch 23: early stopping
# 1/1 [==============================] - 0s 152ms/step
# fold 3 MAE: 0.23750916123390198
# Epoch 1/50
# 7/7 [==============================] - ETA: 0s - loss: 1.6539 - accuracy: 0.1964
# Epoch 1: val_loss improved from inf to 1.53906, saving model to /content/gdrive/My Drive/data/VGG16model5.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7/7 [==============================] - 7s 501ms/step - loss: 1.6539 - accuracy: 0.1964 - val_loss: 1.5391 - val_accuracy: 0.2812 - lr: 2.0000e-04
# Epoch 2/50
# 7/7 [==============================] - ETA: 0s - loss: 1.5312 - accuracy: 0.3929
# Epoch 2: val_loss improved from 1.53906 to 1.28115, saving model to /content/gdrive/My Drive/data/VGG16model5.h5
# 7/7 [==============================] - 2s 332ms/step - loss: 1.5312 - accuracy: 0.3929 - val_loss: 1.2812 - val_accuracy: 0.5625 - lr: 2.0000e-04
# Epoch 3/50
# 7/7 [==============================] - ETA: 0s - loss: 1.4232 - accuracy: 0.3839
# Epoch 3: val_loss improved from 1.28115 to 1.21775, saving model to /content/gdrive/My Drive/data/VGG16model5.h5
# 7/7 [==============================] - 3s 498ms/step - loss: 1.4232 - accuracy: 0.3839 - val_loss: 1.2177 - val_accuracy: 0.5625 - lr: 2.0000e-04
# Epoch 4/50
# 7/7 [==============================] - ETA: 0s - loss: 1.2605 - accuracy: 0.4286
# Epoch 4: val_loss improved from 1.21775 to 1.02571, saving model to /content/gdrive/My Drive/data/VGG16model5.h5
# 7/7 [==============================] - 3s 391ms/step - loss: 1.2605 - accuracy: 0.4286 - val_loss: 1.0257 - val_accuracy: 0.5625 - lr: 2.0000e-04
# Epoch 5/50
# 7/7 [==============================] - ETA: 0s - loss: 1.1458 - accuracy: 0.4643
# Epoch 5: val_loss improved from 1.02571 to 0.83767, saving model to /content/gdrive/My Drive/data/VGG16model5.h5
# 7/7 [==============================] - 3s 369ms/step - loss: 1.1458 - accuracy: 0.4643 - val_loss: 0.8377 - val_accuracy: 0.5938 - lr: 2.0000e-04
# Epoch 6/50
# 7/7 [==============================] - ETA: 0s - loss: 1.1272 - accuracy: 0.5446
# Epoch 6: val_loss did not improve from 0.83767
# 7/7 [==============================] - 2s 287ms/step - loss: 1.1272 - accuracy: 0.5446 - val_loss: 0.8919 - val_accuracy: 0.6250 - lr: 2.0000e-04
# Epoch 7/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9471 - accuracy: 0.6071
# Epoch 7: val_loss improved from 0.83767 to 0.62404, saving model to /content/gdrive/My Drive/data/VGG16model5.h5
# 7/7 [==============================] - 3s 380ms/step - loss: 0.9471 - accuracy: 0.6071 - val_loss: 0.6240 - val_accuracy: 0.6875 - lr: 2.0000e-04
# Epoch 8/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8426 - accuracy: 0.6429
# Epoch 8: val_loss did not improve from 0.62404
# 7/7 [==============================] - 2s 284ms/step - loss: 0.8426 - accuracy: 0.6429 - val_loss: 0.8610 - val_accuracy: 0.6562 - lr: 2.0000e-04
# Epoch 9/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8046 - accuracy: 0.6518
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
#
# Epoch 9: val_loss did not improve from 0.62404
# 7/7 [==============================] - 3s 374ms/step - loss: 0.8046 - accuracy: 0.6518 - val_loss: 0.6550 - val_accuracy: 0.7500 - lr: 2.0000e-04
# Epoch 10/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6559 - accuracy: 0.7589
# Epoch 10: val_loss did not improve from 0.62404
# 7/7 [==============================] - 2s 337ms/step - loss: 0.6559 - accuracy: 0.7589 - val_loss: 0.6357 - val_accuracy: 0.7188 - lr: 1.0000e-04
# Epoch 11/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6466 - accuracy: 0.7679
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 11: val_loss did not improve from 0.62404
# 7/7 [==============================] - 2s 302ms/step - loss: 0.6466 - accuracy: 0.7679 - val_loss: 0.7435 - val_accuracy: 0.6875 - lr: 1.0000e-04
# Epoch 12/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5882 - accuracy: 0.7679
# Epoch 12: val_loss did not improve from 0.62404
# 7/7 [==============================] - 2s 265ms/step - loss: 0.5882 - accuracy: 0.7679 - val_loss: 0.8710 - val_accuracy: 0.6875 - lr: 5.0000e-05
# Epoch 12: early stopping
# 1/1 [==============================] - 0s 171ms/step
# fold 4 MAE: 0.2750000059604645
# CV score: 0.2275020331144333
